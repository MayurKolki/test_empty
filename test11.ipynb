# %%
import pandas as pd
from pandasql import sqldf
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df=pd.read_excel("C:/Users/Admin/Downloads/Hanon.xlsx",sheet_name='November IP Blocking')
df1=pd.read_excel("C:/Users/Admin/Downloads/Hanon.xlsx",sheet_name='November SLA')
# Out:
# D:\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
q="df1.'Incident Generated Date', df.* from df left join df1 on df1.'Incident No raised against QRadar Offense'=df.'Incident' " 
hanon = sqldf(q,globals())
hanon.head()

# %%
df.'Incident'

# %%
len(df)
# Out:
# 119

# %%
len(df1)
# Out:
# 1191

# %%
df.columns
# Out:
# Index(['Date', 'Offense ID', 'Incident', 'Catalog Task', 'Priority',
#        'IP Blocked on firewall', 'Short Description', 'Raised by', 'Remarks'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Sr No', 'Offense Triggered Date', 'Description',
#        'Incident Generated Date', 'QRadar Offense ID',
#        'Incident No raised against QRadar Offense', 'Priority',
#        'Corresponding Catalog Task no. for P2 incident',
#        'Time(KST) when Incident occurred', 'Time(KST) when Incident Created ',
#        'Time taken to raise incidents(I-H)',
#        'Within Response SLA limits(P2 - 1hr/P3 - 8hr)',
#        'Time(KST) when Analysis and Recommendation provided on incident',
#        'Time taken to put analysis and Recommendation(L-H)',
#        'Within Analysis and Recommendation SLA\n(P2 - 2hr/P3 - 8hr)',
#        'Remarks', 'Incident raised by'],
#       dtype='object')

# %%
df1['Offense Triggered Date']
# Out:
# 0      2023-11-01
# 1      2023-11-01
# 2      2023-11-01
# 3      2023-11-01
# 4      2023-11-01
# 5      2023-11-01
# 6      2023-11-01
# 7      2023-11-01
# 8      2023-11-01
# 9      2023-11-01
# 10     2023-11-01
# 11     2023-11-01
# 12     2023-11-01
# 13     2023-11-01
# 14     2023-11-01
# 15     2023-11-01
# 16     2023-11-01
# 17     2023-11-01
# 18     2023-11-01
# 19     2023-11-01
# 20     2023-11-01
# 21     2023-11-01
# 22     2023-11-01
# 23     2023-11-02
# 24     2023-11-02
# 25     2023-11-02
# 26     2023-11-02
# 27     2023-11-02
# 28     2023-11-02
# 29     2023-11-02
# 30     2023-11-02
# 31     2023-11-02
# 32     2023-11-02
# 33     2023-11-02
# 34     2023-11-02
# 35     2023-11-02
# 36     2023-11-02
# 37     2023-11-02
# 38     2023-11-02
# 39     2023-11-02
# 40     2023-11-02
# 41     2023-11-02
# 42     2023-11-02
# 43     2023-11-02
# 44     2023-11-02
# 45     2023-11-02
# 46     2023-11-02
# 47     2023-11-02
# 48     2023-11-03
# 49     2023-11-03
# ...

# %%
df1[df1['Incident No raised against QRadar Offense']=='INC3373581']
# Out:
#        Sr No Offense Triggered Date  \
# 1172  1182.0             2023-12-30
#
#                                             Description  \
# 1172  Suspicious Windows Inbound Communication obser...
#
#      Incident Generated Date QRadar Offense ID  \
# 1172              2023-12-30            437307
#
#      Incident No raised against QRadar Offense Priority  \
# 1172                                INC3373581       P2
#
#      Corresponding Catalog Task no. for P2 incident  \
# 1172                  SCTASK0293780||SCTASK0293782
#
#      Time(KST) when Incident occurred Time(KST) when Incident Created   \
# 1172                         01:19:00                         01:27:00
#
#      Time taken to raise incidents(I-H)  \
# 1172                           00:08:00
#
#      Within Response SLA limits(P2 - 1hr/P3 - 8hr)  \
# 1172                                           Yes
#
#      Time(KST) when Analysis and Recommendation provided on incident  \
# ...

# %%
df11 =df1[['Incident No raised against QRadar Offense','Offense Triggered Date']]

# %%
ro=pd.merge(df, df11, left_on='Incident', right_on='Incident No raised against QRadar Offense', how='left')

# %%
ro.to_csv("rohin1.csv")

# %%
ro
# Out:
#                     Date      Offense ID       Incident  \
# 0             11/29/2023          431364     INC3298098
# 1             11/29/2023          431374     INC3298216
# 2             11/29/2023          431422     INC3299306
# 3             11/29/2023          431644     INC3302815
# 4             11/29/2023          431649     INC3303054
# 5             11/29/2023          431665     INC3303445
# 6             11/29/2023          431667     INC3303457
# 7             11/29/2024          431724     INC3304982
# 8             11/29/2025          431794   INC3305139
# 9             11/29/2026          431820     INC3305256
# 10            11/29/2027          431959   INC3306173
# 11   2028-12-04 00:00:00          432079     INC3307429
# 12                   NaN          432118     INC3308040
# 13                   NaN          432199     INC3308833
# 14                   NaN          432272     INC3309260
# 15                   NaN          432216     INC3308871
# ...

# %%
df11
# Out:
#      Incident No raised against QRadar Offense Offense Triggered Date
# 0                                   INC3187715             2023-11-01
# 1                                   INC3188082             2023-11-01
# 2                                   INC3188167             2023-11-01
# 3                                   INC3188271             2023-11-01
# 4                                   INC3188374             2023-11-01
# 5                                   INC3188586             2023-11-01
# 6                                   INC3189069             2023-11-01
# 7                                   INC3189076             2023-11-01
# 8                                   INC3189261             2023-11-01
# 9                                   INC3189259             2023-11-01
# 10                                  INC3189208             2023-11-01
# 11                                  INC3189346             2023-11-01
# ...
